# %% [markdown]
# ## Imports Necessários

# %%
import tensorflow as tf
import numpy as np

# %% [markdown]
# ## Utilização do modelo EfficientNetB4

# %%
model = tf.keras.applications.EfficientNetB4(
    include_top=False,
    weights='imagenet',
    input_shape=(380, 380, 3),
    pooling='avg',
)

# %% [markdown]
# ## Utilizando o DataSet RDD2020
